# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.12.0)
# Requirement already satisfied: torchvision in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.27.0)
# Requirement already satisfied: torchaudio in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.11.0)
# Requirement already satisfied: filelock in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: numpy in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import torch
print(torch.__version__)  # This will print the installed PyTorch version
# Out:
# 2.12.0+cpu

# %%
x = torch.rand(3, 3)  # Creates a 3x3 random tensor
print(x)
# Out:
# tensor([[0.7352, 0.2744, 0.6360],
#         [0.6460, 0.5927, 0.4804],
#         [0.9791, 0.9944, 0.4165]])
